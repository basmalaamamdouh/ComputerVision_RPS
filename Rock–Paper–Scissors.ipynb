# %%
# Cell 1: Title, Imports, and Setup

# # Rock–Paper–Scissors Simulation, Analysis, and Tkinter Interface
# ### Computer Vision Course — Semester Project

from game_logic import play_round, get_random_move, get_smarter_move
from simulate import simulate_n_rounds, plot_stats

# %%
# Cell 2: Run 20 Rounds (Shows high fluctuation)
stats_20 = simulate_n_rounds(20)
print(stats_20)
plot_stats(stats_20)
# Out:
# {'rounds': 20, 'results': {'player': 5, 'computer': 7, 'draw': 8}, 'player_moves': {'rock': 5, 'paper': 8, 'scissors': 7}, 'comp_moves': {'rock': 10, 'paper': 5, 'scissors': 5}, 'percentages': {'player_win_pct': 25.0, 'computer_win_pct': 35.0, 'draw_pct': 40.0}, 'player_move_pct': {'rock': 25.0, 'paper': 40.0, 'scissors': 35.0}, 'comp_move_pct': {'rock': 50.0, 'paper': 25.0, 'scissors': 25.0}}
# C:\Users\acs\ComputerVisionProject_RPS\simulate.py:75: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Cell 3: Run 100 Rounds (Intermediate stability)
stats_100 = simulate_n_rounds(100)
print(stats_100)
plot_stats(stats_100)
# Out:
# {'rounds': 100, 'results': {'player': 32, 'computer': 36, 'draw': 32}, 'player_moves': {'rock': 33, 'paper': 28, 'scissors': 39}, 'comp_moves': {'rock': 34, 'paper': 34, 'scissors': 32}, 'percentages': {'player_win_pct': 32.0, 'computer_win_pct': 36.0, 'draw_pct': 32.0}, 'player_move_pct': {'rock': 33.0, 'paper': 28.000000000000004, 'scissors': 39.0}, 'comp_move_pct': {'rock': 34.0, 'paper': 34.0, 'scissors': 32.0}}
# C:\Users\acs\ComputerVisionProject_RPS\simulate.py:75: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Cell 4: Run 500 Rounds (Law of Large Numbers Proof)
stats_500 = simulate_n_rounds(500)
print(stats_500)
plot_stats(stats_500)
# Out:
# {'rounds': 500, 'results': {'player': 151, 'computer': 181, 'draw': 168}, 'player_moves': {'rock': 164, 'paper': 164, 'scissors': 172}, 'comp_moves': {'rock': 162, 'paper': 177, 'scissors': 161}, 'percentages': {'player_win_pct': 30.2, 'computer_win_pct': 36.199999999999996, 'draw_pct': 33.6}, 'player_move_pct': {'rock': 32.800000000000004, 'paper': 32.800000000000004, 'scissors': 34.4}, 'comp_move_pct': {'rock': 32.4, 'paper': 35.4, 'scissors': 32.2}}
# C:\Users\acs\ComputerVisionProject_RPS\simulate.py:75: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Cell 5: Run AI Test (Random Player vs. Smart Computer - 500 rounds)
smart_stats = simulate_n_rounds(
    500, 
    player_strategy=get_random_move, # The Player is random
    comp_strategy=get_smarter_move   # The Computer is your AI
)
print(smart_stats)
plot_stats(smart_stats)
# Out:
# {'rounds': 500, 'results': {'player': 158, 'computer': 174, 'draw': 168}, 'player_moves': {'rock': 167, 'paper': 162, 'scissors': 171}, 'comp_moves': {'rock': 136, 'paper': 196, 'scissors': 168}, 'percentages': {'player_win_pct': 31.6, 'computer_win_pct': 34.8, 'draw_pct': 33.6}, 'player_move_pct': {'rock': 33.4, 'paper': 32.4, 'scissors': 34.2}, 'comp_move_pct': {'rock': 27.200000000000003, 'paper': 39.2, 'scissors': 33.6}}
# C:\Users\acs\ComputerVisionProject_RPS\simulate.py:75: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
